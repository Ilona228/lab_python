# %%
dna_colichestvo = input("введите последовательность нуклеотидов")
dlina = len(dna_colichestvo)
lol = dlina > 0
print("э", lol)
weight = dlina * 330
print("последовательность нуклеотидов:", dlina, ", вес", weight, "нуклонов")
a = dna_colichestvo.count("A")
print("у вас целых",a,"А")
# Out:
# введите последовательность нуклеотидовAA
# э True
# последовательность нуклеотидов: 2 , вес 660 нуклонов
# у вас целых 2 А

# %%
anus_v_govne = True
popa_clean = False
sosok_norm = True
if anus_v_govne and popa_clean or not sosok_norm:
  print('lol')
else:
  print('blya()')
# Out:
# lol

# %%
a = input('kak dela').lower()
if "хорошо" in a:
  print("выздоравливай")
elif "мать" in a:
  print('lfdyj gj gbplt yt gjkexfk')
else:
  print("круто")
# Out:
# kak delaок
# круто

# %%
dima = 'gryaznый'
dima_perdit = False

if dima_perdit:
  if dima == 'gryaznый':
    print('pezdets')
  else:
    print('blya()')
else:
  print('))))')
# Out:
# ))))

# %%
a = input("введите уровень экспрессии гена: ")
a= int(a)
if a>75:
  print('too high bro')
elif a>25 and a<75:
  print("norm bro")
elif a<25 and a>0:
  print("bad")
elif a<0:
  print("bro....")
# Out:
# введите уровень экспрессии гена: -30
# bro....
